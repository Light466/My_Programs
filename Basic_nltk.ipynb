# %% [markdown]
# <a href="https://colab.research.google.com/github/Light466/My_Programs/blob/main/Basic_nltk.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import nltk
from nltk.tokenize import word_tokenize

nltk.download('punkt')
nltk.download('punkt_tab')

text = "I love Natural Language Processing."

tokens = word_tokenize(text)

print(tokens)
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# ['I', 'love', 'Natural', 'Language', 'Processing', '.']

# %%
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize

nltk.download('stopwords')
nltk.download('punkt')
nltk.download('punkt_tab')

text = "The student is studying artificial intelligence."

tokens = word_tokenize(text)

stop_words = set(stopwords.words('english'))

filtered_words = []

for word in tokens:
    if word.lower() not in stop_words:
        filtered_words.append(word)

print("Original:")
print(tokens)

print("After stop-word removal:")
print(filtered_words)
# Out:
# Original:
# ['The', 'student', 'is', 'studying', 'artificial', 'intelligence', '.']
# After stop-word removal:
# ['student', 'studying', 'artificial', 'intelligence', '.']
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!

# %%
from nltk.stem import PorterStemmer

stemmer = PorterStemmer()

words = [
    "play",
    "playing",
    "played",
    "plays",
    "player"
]

for word in words:
    print(word, "->", stemmer.stem(word))
# Out:
# play -> play
# playing -> play
# played -> play
# plays -> play
# player -> player

# %%
import nltk

from nltk.stem import WordNetLemmatizer

nltk.download('wordnet')
nltk.download('omw-1.4')

lemmatizer = WordNetLemmatizer()

words = ["playing", "played", "cars", "children"]

for word in words:
    print(word, "->", lemmatizer.lemmatize(word))
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# playing -> playing
# played -> played
# cars -> car
# children -> child
