# %%
import pandas as pd

# %%
df=pd.read_csv("heart_attack_youngsters_india.csv")

# %%
df
# Out:
#       Age  Gender      Region Urban/Rural     SES Smoking Status  \
# 0      30    Male        East       Urban  Middle          Never
# 1      24  Female        East       Urban     Low   Occasionally
# 2      24  Female       North       Urban     Low   Occasionally
# 3      27    Male        East       Urban  Middle   Occasionally
# 4      21  Female        West       Rural     Low   Occasionally
# ...   ...     ...         ...         ...     ...            ...
# 9995   33  Female        East       Rural     Low   Occasionally
# 9996   35  Female  North-East       Rural     Low   Occasionally
# 9997   32    Male        West       Urban  Middle      Regularly
# 9998   21  Female     Central       Rural  Middle      Regularly
# 9999   28    Male       North       Rural    High          Never
#
#      Alcohol Consumption       Diet Type Physical Activity Level  \
# 0              Regularly  Non-Vegetarian               Sedentary
# ...

# %%
df.head()
# Out:
#    Age  Gender Region Urban/Rural     SES Smoking Status Alcohol Consumption  \
# 0   30    Male   East       Urban  Middle          Never           Regularly
# 1   24  Female   East       Urban     Low   Occasionally        Occasionally
# 2   24  Female  North       Urban     Low   Occasionally        Occasionally
# 3   27    Male   East       Urban  Middle   Occasionally               Never
# 4   21  Female   West       Rural     Low   Occasionally        Occasionally
#
#         Diet Type Physical Activity Level  Screen Time (hrs/day)  ...  \
# 0  Non-Vegetarian               Sedentary                      3  ...
# 1  Non-Vegetarian               Sedentary                     15  ...
# 2           Vegan                    High                     15  ...
# 3      Vegetarian               Sedentary                      6  ...
# 4      Vegetarian                Moderate                      4  ...
#
#    Stress Level Blood Pressure (systolic/diastolic mmHg)  \
# ...

# %%
df.describe()
# Out:
#                 Age  Screen Time (hrs/day)  Sleep Duration (hrs/day)  \
# count  10000.000000           10000.000000              10000.000000
# mean      26.601500               7.510700                  6.489600
# std        5.164239               4.626578                  2.289327
# min       18.000000               0.000000                  3.000000
# 25%       22.000000               4.000000                  4.000000
# 50%       27.000000               8.000000                  6.000000
# 75%       31.000000              12.000000                  8.000000
# max       35.000000              15.000000                 10.000000
#
#        Cholesterol Levels (mg/dL)  BMI (kg/m²)  Resting Heart Rate (bpm)  \
# count                10000.000000  10000.00000              10000.000000
# mean                   199.649000     27.44190                 89.493400
# std                     57.561902      7.22374                 17.318237
# ...

# %%
#Binary Classification
#converting categorial data into numeric format
df['Gender'].replace({'Male':'0','Female':'1'},inplace=True)

# %%
df
# Out:
#       Age Gender      Region Urban/Rural     SES Smoking Status  \
# 0      30      0        East       Urban  Middle          Never
# 1      24      1        East       Urban     Low   Occasionally
# 2      24      1       North       Urban     Low   Occasionally
# 3      27      0        East       Urban  Middle   Occasionally
# 4      21      1        West       Rural     Low   Occasionally
# ...   ...    ...         ...         ...     ...            ...
# 9995   33      1        East       Rural     Low   Occasionally
# 9996   35      1  North-East       Rural     Low   Occasionally
# 9997   32      0        West       Urban  Middle      Regularly
# 9998   21      1     Central       Rural  Middle      Regularly
# 9999   28      0       North       Rural    High          Never
#
#      Alcohol Consumption       Diet Type Physical Activity Level  \
# 0              Regularly  Non-Vegetarian               Sedentary
# ...

# %%
import matplotlib.pyplot as plt
plt.scatter(x='Age',y='Gender',data=df)

# %%
#Splitting the data into training dataset and testing dataset
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(df[['Age']],df['Gender'],test_size=0.2)

# %%
len(x_train)
# Out:
# 8000

# %%
len(x_test)
# Out:
# 2000

# %%
x_test
# Out:
#       Age
# 400    32
# 8670   35
# 5948   34
# 9491   18
# 2871   31
# ...   ...
# 7399   30
# 5655   32
# 5250   28
# 8537   22
# 6985   22
#
# [2000 rows x 1 columns]

# %%
len(y_train)
# Out:
# 8000

# %%
x_train.shape
# Out:
# (8000, 1)

# %%
y_test
# Out:
# 400     1
# 8670    0
# 5948    0
# 9491    0
# 2871    1
#        ..
# 7399    1
# 5655    0
# 5250    1
# 8537    0
# 6985    1
# Name: Gender, Length: 2000, dtype: object

# %%
#Building a Logistic Regression model
from sklearn.linear_model import LogisticRegression

# %%
#Creating the object of logistic regression class
lr=LogisticRegression()

# %%
#Training the model
lr.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
#Predicting the values
lr.predict(x_test)
# Out:
# array(['1', '1', '1', ..., '1', '0', '0'], dtype=object)

# %%
lr.predict([[60]])
# Out:
# c:\users\lenovo\appdata\local\programs\python\python37\lib\site-packages\sklearn\base.py:451: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   "X does not have valid feature names, but"
# array(['1'], dtype=object)

# %%
lr.predict([[15]])
# Out:
# c:\users\lenovo\appdata\local\programs\python\python37\lib\site-packages\sklearn\base.py:451: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   "X does not have valid feature names, but"
# array(['0'], dtype=object)

# %%
lr.predict([[57]])
# Out:
# c:\users\lenovo\appdata\local\programs\python\python37\lib\site-packages\sklearn\base.py:451: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   "X does not have valid feature names, but"
# array(['1'], dtype=object)

# %%
lr.predict([[30]])
# Out:
# c:\users\lenovo\appdata\local\programs\python\python37\lib\site-packages\sklearn\base.py:451: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   "X does not have valid feature names, but"
# array(['1'], dtype=object)

# %%
lr.predict([[29]])
# Out:
# c:\users\lenovo\appdata\local\programs\python\python37\lib\site-packages\sklearn\base.py:451: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   "X does not have valid feature names, but"
# array(['1'], dtype=object)

# %%
#Multiclass Classification
#EDA(Exploratory Data Analysis)
df.head()
# Out:
#    Age Gender Region Urban/Rural     SES Smoking Status Alcohol Consumption  \
# 0   30      0   East       Urban  Middle          Never           Regularly
# 1   24      1   East       Urban     Low   Occasionally        Occasionally
# 2   24      1  North       Urban     Low   Occasionally        Occasionally
# 3   27      0   East       Urban  Middle   Occasionally               Never
# 4   21      1   West       Rural     Low   Occasionally        Occasionally
#
#         Diet Type Physical Activity Level  Screen Time (hrs/day)  ...  \
# 0  Non-Vegetarian               Sedentary                      3  ...
# 1  Non-Vegetarian               Sedentary                     15  ...
# 2           Vegan                    High                     15  ...
# 3      Vegetarian               Sedentary                      6  ...
# 4      Vegetarian                Moderate                      4  ...
#
#    Stress Level Blood Pressure (systolic/diastolic mmHg)  \
# ...

# %%
df.tail()
# Out:
#       Age Gender      Region Urban/Rural     SES Smoking Status  \
# 9995   33      1        East       Rural     Low   Occasionally
# 9996   35      1  North-East       Rural     Low   Occasionally
# 9997   32      0        West       Urban  Middle      Regularly
# 9998   21      1     Central       Rural  Middle      Regularly
# 9999   28      0       North       Rural    High          Never
#
#      Alcohol Consumption       Diet Type Physical Activity Level  \
# 9995        Occasionally           Vegan               Sedentary
# 9996               Never           Vegan                    High
# 9997               Never  Non-Vegetarian                Moderate
# 9998               Never           Vegan               Sedentary
# 9999               Never      Vegetarian               Sedentary
#
#       Screen Time (hrs/day)  ...  Stress Level  \
# 9995                      2  ...           Low
# 9996                     14  ...           Low
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 26 columns):
#  #   Column                                    Non-Null Count  Dtype
# ---  ------                                    --------------  -----
#  0   Age                                       10000 non-null  int64
#  1   Gender                                    10000 non-null  object
#  2   Region                                    10000 non-null  object
#  3   Urban/Rural                               10000 non-null  object
#  4   SES                                       10000 non-null  object
#  5   Smoking Status                            10000 non-null  object
#  6   Alcohol Consumption                       10000 non-null  object
#  7   Diet Type                                 10000 non-null  object
#  8   Physical Activity Level                   10000 non-null  object
#  9   Screen Time (hrs/day)                     10000 non-null  int64
# ...

# %%
df.describe()
# Out:
#                 Age  Screen Time (hrs/day)  Sleep Duration (hrs/day)  \
# count  10000.000000           10000.000000              10000.000000
# mean      26.601500               7.510700                  6.489600
# std        5.164239               4.626578                  2.289327
# min       18.000000               0.000000                  3.000000
# 25%       22.000000               4.000000                  4.000000
# 50%       27.000000               8.000000                  6.000000
# 75%       31.000000              12.000000                  8.000000
# max       35.000000              15.000000                 10.000000
#
#        Cholesterol Levels (mg/dL)  BMI (kg/m²)  Resting Heart Rate (bpm)  \
# count                10000.000000  10000.00000              10000.000000
# mean                   199.649000     27.44190                 89.493400
# std                     57.561902      7.22374                 17.318237
# ...

# %%
df.describe
# Out:
# <bound method NDFrame.describe of       Age Gender      Region Urban/Rural     SES Smoking Status  \
# 0      30      0        East       Urban  Middle          Never
# 1      24      1        East       Urban     Low   Occasionally
# 2      24      1       North       Urban     Low   Occasionally
# 3      27      0        East       Urban  Middle   Occasionally
# 4      21      1        West       Rural     Low   Occasionally
# ...   ...    ...         ...         ...     ...            ...
# 9995   33      1        East       Rural     Low   Occasionally
# 9996   35      1  North-East       Rural     Low   Occasionally
# 9997   32      0        West       Urban  Middle      Regularly
# 9998   21      1     Central       Rural  Middle      Regularly
# 9999   28      0       North       Rural    High          Never
#
#      Alcohol Consumption       Diet Type Physical Activity Level  \
# 0              Regularly  Non-Vegetarian               Sedentary
# ...

# %%
#Checking unique values from Smoking Status
df['Smoking Status'].unique
# Out:
# <bound method Series.unique of 0              Never
# 1       Occasionally
# 2       Occasionally
# 3       Occasionally
# 4       Occasionally
#             ...
# 9995    Occasionally
# 9996    Occasionally
# 9997       Regularly
# 9998       Regularly
# 9999           Never
# Name: Smoking Status, Length: 10000, dtype: object>

# %%
#Converting the categorial data into numerical format
df['Smoking Status'].replace({'Occasionally':'1','Regularly':'2','Never':'3'},inplace=True)

# %%
df
# Out:
#       Age Gender      Region Urban/Rural     SES Smoking Status  \
# 0      30      0        East       Urban  Middle              3
# 1      24      1        East       Urban     Low              1
# 2      24      1       North       Urban     Low              1
# 3      27      0        East       Urban  Middle              1
# 4      21      1        West       Rural     Low              1
# ...   ...    ...         ...         ...     ...            ...
# 9995   33      1        East       Rural     Low              1
# 9996   35      1  North-East       Rural     Low              1
# 9997   32      0        West       Urban  Middle              2
# 9998   21      1     Central       Rural  Middle              2
# 9999   28      0       North       Rural    High              3
#
#      Alcohol Consumption       Diet Type Physical Activity Level  \
# 0              Regularly  Non-Vegetarian               Sedentary
# ...

# %%
#Splitting the data into training and testing dataset
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(df[['Age','Screen Time (hrs/day)','Resting Heart Rate (bpm)','Maximum Heart Rate Achieved','Triglyceride Levels (mg/dL)']],df['Smoking Status'],test_size=0.2)

# %%
len(x_train)
# Out:
# 8000

# %%
len(x_test)
# Out:
# 2000

# %%
x_train
# Out:
#       Age  Screen Time (hrs/day)  Resting Heart Rate (bpm)  \
# 3201   23                      9                        75
# 2662   32                      1                       101
# 3768   22                      1                       100
# 1718   20                     12                        95
# 6205   19                     15                        77
# ...   ...                    ...                       ...
# 7508   27                     14                        92
# 7065   21                      0                       109
# 292    24                      6                        76
# 5713   21                     12                        64
# 5079   20                      3                        76
#
#       Maximum Heart Rate Achieved  Triglyceride Levels (mg/dL)
# 3201                          134                          173
# 2662                          210                          307
# 3768                          164                           92
# ...

# %%
y_train
# Out:
# 3201    3
# 2662    3
# 3768    3
# 1718    3
# 6205    3
#        ..
# 7508    3
# 7065    3
# 292     1
# 5713    3
# 5079    3
# Name: Smoking Status, Length: 8000, dtype: object

# %%
#Building the Logistic Regression model
from sklearn.linear_model import LogisticRegression

# %%
#Creating the object of LogisticRegression class
lr=LogisticRegression()

# %%
#Providing the training data to model i.e we are Training the model
lr.fit(x_train,y_train)
# Out:
# c:\users\lenovo\appdata\local\programs\python\python37\lib\site-packages\sklearn\linear_model\_logistic.py:818: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG,
# LogisticRegression()

# %%
lr.fit(x_train,y_train)
# Out:
# c:\users\lenovo\appdata\local\programs\python\python37\lib\site-packages\sklearn\linear_model\_logistic.py:818: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG,
# LogisticRegression()

# %%
lr.predict(x_test)
# Out:
# array(['3', '3', '3', ..., '3', '3', '3'], dtype=object)

# %%
x_test
# Out:
#       Age  Screen Time (hrs/day)  Resting Heart Rate (bpm)  \
# 8258   31                      6                       113
# 3176   32                     14                        95
# 6761   30                      8                       115
# 9702   25                      7                       109
# 9305   24                     13                        83
# ...   ...                    ...                       ...
# 3542   26                      0                        98
# 748    32                      1                        86
# 6473   31                      5                        60
# 8003   35                      9                       100
# 9619   32                     14                        73
#
#       Maximum Heart Rate Achieved  Triglyceride Levels (mg/dL)
# 8258                          142                          307
# 3176                          118                          286
# 6761                          202                          276
# ...

# %%
lr.predict([[21	,15	,64	,158	,469]])
# Out:
# c:\users\lenovo\appdata\local\programs\python\python37\lib\site-packages\sklearn\base.py:451: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   "X does not have valid feature names, but"
# array(['3'], dtype=object)

# %%
#Checking Accuracy of model predictions
lr.score(x_test,y_test)
# Out:
# 0.4835
